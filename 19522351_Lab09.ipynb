# %% [markdown]
# #Thông tin sinh viên
# #MSSV: 19522351
# #Họ và tên: Trần Trung Tín

# %% [markdown]
# #Install Package & Load MNIST Dataset

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Add, AveragePooling2D
from keras.models import load_model, Model
#from keras.objectives import categorical_crossentropy
from keras.datasets import mnist
from collections import Counter
from sklearn import preprocessing

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
def onehot(y):
  oh = np.zeros((y.shape[0], 10))
  for i in range(y.shape[0]):
    oh[i, int(y[i])]=1
  return oh

def norm_zero_one(x_train):
  min_val = np.min(x_train)
  max_val = np.max(x_train)
  x_train_norm = (x_train-min_val)/(max_val-min_val)
  return x_train_norm

def norm_normal_dist(x_train):
  mean_val = np.mean(x_train)
  std_val = np.std(x_train)
  x_train_norm = (x_train-mean_val)/std_val
  return x_train_norm

# %%
#normalize data
y_train_oh = onehot(y_train)
y_train_oh.shape

y_test_oh = onehot(y_test)
y_test_oh.shape

x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

# %% [markdown]
# #Install LeNetCNN

# %%
#base
class LeNetCNN:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    C1 = Conv2D(6, (3, 3), padding='same', activation='relu')(input)
    S2 = MaxPooling2D(pool_size=(2, 2), padding="same")(C1)
    C3 = Conv2D(16, (3, 3), padding='same', activation='relu')(S2)
    S4 = MaxPooling2D(pool_size=(2, 2), padding="same")(C3)

    flat = Flatten()(S4)
    # These like ANN
    F5 = Dense(120, activation='relu', use_bias=True)(flat)
    F6 = Dense(84, activation='relu', use_bias=True)(F5)
    output = Dense(10, activation='softmax', use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %%
#LeNetCNN without Activation
class LeNetCNN_v1:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    C1 = Conv2D(6, (3, 3), padding='same')(input)
    S2 = MaxPooling2D(pool_size=(2, 2), padding="same")(C1)
    C3 = Conv2D(16, (3, 3), padding='same')(S2)
    S4 = MaxPooling2D(pool_size=(2, 2), padding="same")(C3)

    flat = Flatten()(S4)
    # These like ANN
    F5 = Dense(120, use_bias=True)(flat)
    F6 = Dense(84, use_bias=True)(F5)
    output = Dense(10, use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %%
from keras.layers.convolutional.separable_conv2d import SeparableConv2D
#LeNetCNN without Convolutional Layer
class LeNetCNN_v2:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    S2 = MaxPooling2D(pool_size=(2, 2), padding="same")(input)
    S4 = MaxPooling2D(pool_size=(2, 2), padding="same")(S2)

    flat = Flatten()(S4)
    # These like ANN
    F5 = Dense(120, activation='relu', use_bias=True)(flat)
    F6 = Dense(84, activation='relu', use_bias=True)(F5)
    output = Dense(10, activation='softmax', use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %%
#LeNetCNN without Pooling Layer
class LeNetCNN_v3:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    C1 = Conv2D(6, (3, 3), padding='same', activation='relu')(input)
    C3 = Conv2D(16, (3, 3), padding='same', activation='relu')(C1)

    flat = Flatten()(C3)
    # These like ANN
    F5 = Dense(120, activation='relu', use_bias=True)(flat)
    F6 = Dense(84, activation='relu', use_bias=True)(F5)
    output = Dense(10, activation='softmax', use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %% [markdown]
# #Base LeNetCNN

# %%
lenet = LeNetCNN()
lenet.build((28,28,1))
lenet.summary()
lenet.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         60
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        880
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 120)               94200
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 106,154
# Trainable params: 106,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] -
ms/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 0.0521 - val_accuracy: 0.9835
# Epoch 28/50
# 469/469 [==============================] - 18s 37ms/step - loss: 0.0425 - accuracy: 0.9870 - val_loss: 0.0453 - val_accuracy: 0.9840
# Epoch 29/50
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0408 - accuracy: 0.9872 - val_loss: 0.0495 - val_accuracy: 0.9841
# Epoch 30/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0400 - accuracy: 0.9876 - val_loss: 0.0465 - val_accuracy: 0.9843
# Epoch 31/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0381 - accuracy: 0.9885 - val_loss: 0.0465 - val_accuracy: 0.9849
# Epoch 32/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0374 - accuracy: 0.9883 - val_loss: 0.0439 - val_accuracy: 0.9847
# Epoch 33/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0362 - accuracy: 0.9888 - val_loss: 0.0489 - val_accuracy: 0.9842
# Epoch 34/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0356 - accuracy: 0.9889 - val_loss: 0.0430 - val_accuracy: 0.9868
# Epoch 35/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0354 - accuracy: 0.9888 - val_loss: 0.0440 - val_accuracy: 0.9851
# Epoch 36/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0338 - accuracy: 0.9897 - val_loss: 0.0400 - val_accuracy: 0.9862
# Epoch 37/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0324 - accuracy: 0.9900 - val_loss: 0.0399 - val_accuracy: 0.9864
# Epoch 38/50
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0319 - accuracy: 0.9898 - val_loss: 0.0443 - val_accuracy: 0.9853
# Epoch 39/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0309 - accuracy: 0.9904 - val_loss: 0.0536 - val_accuracy: 0.9831
# Epoch 40/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0301 - accuracy: 0.9909 - val_loss: 0.0415 - val_accuracy: 0.9862
# Epoch 41/50
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0291 - accuracy: 0.9913 - val_loss: 0.0398 - val_accuracy: 0.9868
# Epoch 42/50
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0293 - accuracy: 0.9909 - val_loss: 0.0402 - val_accuracy: 0.9867
# Epoch 43/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.0439 - val_accuracy: 0.9855
# Epoch 44/50
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0270 - accuracy: 0.9917 - val_loss: 0.0408 - val_accuracy: 0.9856
# Epoch 45/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0270 - accuracy: 0.9919 - val_loss: 0.0445 - val_accuracy: 0.9858
# Epoch 46/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0396 - val_accuracy: 0.9866
# Epoch 47/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0249 - accuracy: 0.9921 - val_loss: 0.0408 - val_accuracy: 0.9872
# Epoch 48/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0248 - accuracy: 0.9922 - val_loss: 0.0442 - val_accuracy: 0.9853
# Epoch 49/50
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0240 - accuracy: 0.9929 - val_loss: 0.0382 - val_accuracy: 0.9870
# Epoch 50/50
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.0412 - val_accuracy: 0.9859

# %% [markdown]
# Đánh giá độ chính xác: Mô hình LeNet sau khi train 50 epochs với dataset MNIST thì trả về được accuracy trên tập train cũng như test rất cao lên đến ~99% đối với tập train và ~98% đối với tập test. Điều này cho thấy mô hình dự đoán kết quả dựa trên dữ liệu MNIST là hiệu quả.

# %% [markdown]
# #LenetCNN without activate

# %%
lenet_v1 = LeNetCNN_v1()
lenet_v1.build((28,28,1))
lenet_v1.summary()
lenet_v1.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 6)         60
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 6)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 16)        880
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 120)               94200
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 106,154
# Trainable params: 106,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 17s 34ms/step - loss: 7.7605 - accuracy: 0.1102 - val_loss: 7.8350 - val_accuracy: 0.1063
# Epoch 2/50
# 469/469 [==============================] - 16s 34ms/step - loss: 8.0121 - accuracy: 0.1098 - val_loss: 8.1574 - val_accuracy: 0.1068
# Epoch 3/50
# 469/469 [==============================] - 20s 42ms/step - loss: 8.0121 - accuracy: 0.1093 - val_loss: 8.0091 - val_accuracy: 0.1058
# Epoch 4/50
# 469/469 [==============================] - 16s 34ms/step - loss: 8.0717 - accuracy: 0.1092 - val_loss: 8.0204 - val_accuracy: 0.1056
# Epoch 5/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.0523 - accuracy: 0.1089 - val_loss: 8.0155 - val_accuracy: 0.1055
# Epoch 6/50
# 469/469 [==============================] - 17s 35ms/step - loss: 8.0910 - accuracy: 0.1088 - val_loss: 8.0349 - val_accuracy: 0.1054
# Epoch 7/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.0824 - accuracy: 0.1087 - val_loss: 8.1219 - val_accuracy: 0.1055
# Epoch 8/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1270 - accuracy: 0.1088 - val_loss: 8.1832 - val_accuracy: 0.1054
# Epoch 9/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1552 - accuracy: 0.1089 - val_loss: 8.2251 - val_accuracy: 0.1056
# Epoch 10/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1867 - accuracy: 0.1089 - val_loss: 8.2218 - val_accuracy: 0.1053
# Epoch 11/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1912 - accuracy: 0.1088 - val_loss: 8.1719 - val_accuracy: 0.1053
# Epoch 12/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1829 - accuracy: 0.1086 - val_loss: 8.2799 - val_accuracy: 0.1055
# Epoch 13/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1891 - accuracy: 0.1087 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 14/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 15/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 16/50
# 469/469 [==============================] - 17s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 17/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 18/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 19/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 20/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 21/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 22/50
# 469/469 [==============================] - 16s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 23/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 24/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 25/50
# 469/469 [==============================] - 17s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 26/50
# 469/469 [==============================] - 17s 35ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 27/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 28/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 29/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 30/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 31/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 32/50
# 469/469 [==============================] - 18s 38ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 33/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 34/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 35/50
# 469/469 [==============================] - 18s 39ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 36/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 37/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 38/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 39/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 40/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 41/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 42/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 43/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 44/50
# 469/469 [==============================] - 18s 39ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 45/50
# 469/469 [==============================] - 18s 38ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 46/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 47/50
# 469/469 [==============================] - 18s 38ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 48/50
# 469/469 [==============================] - 17s 37ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 49/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052
# Epoch 50/50
# 469/469 [==============================] - 17s 36ms/step - loss: 8.1799 - accuracy: 0.1086 - val_loss: 8.1574 - val_accuracy: 0.1052

# %% [markdown]
# Đánh giá độ chính xác: Sau khi loại bỏ activation thì độ chính xác của model đã giảm đi rất nhiều khi train/test.

# %% [markdown]
# #LenetCNN without Conv Layer

# %%
lenet_v2 = LeNetCNN_v2()
lenet_v2.build((28,28,1))
lenet_v2.summary()
lenet_v2.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 1)        0
#  2D)
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 1)          0
#  2D)
#
#  flatten_2 (Flatten)         (None, 49)                0
#
#  dense_6 (Dense)             (None, 120)               6000
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 17,014
# Trainable params: 17,014
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 2s 4ms/step - loss: 1.9256 - accuracy: 0.4634 - val_loss: 1.4895 - val_accuracy: 0.6808
# Epoch 2/50
# 469/469 [==============================] - 2s 4ms/step - loss: 1.1703 - accuracy: 0.7086 - val_loss: 0.9291 - val_accuracy: 0.7459
# Epoch 3/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.8366 - accuracy: 0.7564 - val_loss: 0.7457 - val_accuracy: 0.7848
# Epoch 4/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.7122 - accuracy: 0.7854 - val_loss: 0.6630 - val_accuracy: 0.8033
# Epoch 5/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6477 - accuracy: 0.8009 - val_loss: 0.6154 - val_accuracy: 0.8115
# Epoch 6/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6089 - accuracy: 0.8103 - val_loss: 0.5834 - val_accuracy: 0.8223
# Epoch 7/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.
50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3935 - accuracy: 0.8716 - val_loss: 0.4030 - val_accuracy: 0.8717
# Epoch 39/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3907 - accuracy: 0.8724 - val_loss: 0.3951 - val_accuracy: 0.8714
# Epoch 40/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3878 - accuracy: 0.8725 - val_loss: 0.3950 - val_accuracy: 0.8748
# Epoch 41/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3853 - accuracy: 0.8740 - val_loss: 0.3901 - val_accuracy: 0.8755
# Epoch 42/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3824 - accuracy: 0.8753 - val_loss: 0.3882 - val_accuracy: 0.8773
# Epoch 43/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3799 - accuracy: 0.8759 - val_loss: 0.3860 - val_accuracy: 0.8751
# Epoch 44/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3774 - accuracy: 0.8762 - val_loss: 0.3845 - val_accuracy: 0.8774
# Epoch 45/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3749 - accuracy: 0.8776 - val_loss: 0.3814 - val_accuracy: 0.8778
# Epoch 46/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3724 - accuracy: 0.8785 - val_loss: 0.3782 - val_accuracy: 0.8778
# Epoch 47/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3703 - accuracy: 0.8794 - val_loss: 0.3772 - val_accuracy: 0.8787
# Epoch 48/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3678 - accuracy: 0.8800 - val_loss: 0.3768 - val_accuracy: 0.8799
# Epoch 49/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3657 - accuracy: 0.8805 - val_loss: 0.3751 - val_accuracy: 0.8786
# Epoch 50/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3636 - accuracy: 0.8811 - val_loss: 0.3726 - val_accuracy: 0.8811

# %% [markdown]
# Đánh giá độ chính xác: Việc loại bỏ Convolutional Layer có vẻ như một phần ảnh hưởng tới độ chính xác của model khi nó giảm khoảng 10% độ chính xác kể cả trên tập train và tập test.

# %% [markdown]
# #LeNetCNN without Pooling

# %%
lenet_v3 = LeNetCNN_v3()
lenet_v3.build((28,28,1))
lenet_v3.summary()
lenet_v3.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 6)         60
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        880
#
#  flatten_3 (Flatten)         (None, 12544)             0
#
#  dense_9 (Dense)             (None, 120)               1505400
#
#  dense_10 (Dense)            (None, 84)                10164
#
#  dense_11 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 1,517,354
# Trainable params: 1,517,354
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.9667 - accuracy: 0.7039 - val_loss: 0.2850 - val_accuracy: 0.9151
# Epoch 2/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.2449 - accuracy: 0.9268 - val_loss: 0.2147 - val_accuracy: 0.9335
# Epoch 3/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.1832 - accuracy: 0.9451 - val_loss: 0.1517 - val_accuracy: 0.9551
# Epoch 4/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.1480 - accuracy: 0.9552 - val_loss: 0.1473 - val_accuracy: 0.9571
# Epoch 5/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.1265 - accuracy: 0.9617 - val_loss: 0.1315 - val_accuracy: 0.9582
# Epoch 6/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.1102 - accuracy: 0.9663 - val_loss: 0.1106 - val_accuracy: 0.9642
# Epoch 7/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0985 - accuracy: 0.9696 - val_loss: 0.0993 - val_accuracy: 0.9693
# Epoch 8/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0896 - accuracy: 0.9723 - val_loss: 0.0873 - val_accuracy: 0.9727
# Epoch 9/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0832 - accuracy: 0.9740 - val_loss: 0.0851 - val_accuracy: 0.9733
# Epoch 10/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0773 - accuracy: 0.9758 - val_loss: 0.0873 - val_accuracy: 0.9728
# Epoch 11/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0722 - accuracy: 0.9779 - val_loss: 0.0872 - val_accuracy: 0.9717
# Epoch 12/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0670 - accuracy: 0.9794 - val_loss: 0.1020 - val_accuracy: 0.9694
# Epoch 13/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0635 - accuracy: 0.9801 - val_loss: 0.0798 - val_accuracy: 0.9741
# Epoch 14/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.0605 - accuracy: 0.9810 - val_loss: 0.0709 - val_accuracy: 0.9775
# Epoch 15/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0557 - accuracy: 0.9826 - val_loss: 0.0727 - val_accuracy: 0.9770
# Epoch 16/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0536 - accuracy: 0.9832 - val_loss: 0.0752 - val_accuracy: 0.9760
# Epoch 17/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0510 - accuracy: 0.9836 - val_loss: 0.0772 - val_accuracy: 0.9752
# Epoch 18/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0483 - accuracy: 0.9853 - val_loss: 0.0703 - val_accuracy: 0.9776
# Epoch 19/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0458 - accuracy: 0.9853 - val_loss: 0.0760 - val_accuracy: 0.9765
# Epoch 20/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0435 - accuracy: 0.9863 - val_loss: 0.0675 - val_accuracy: 0.9789
# Epoch 21/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0407 - accuracy: 0.9872 - val_loss: 0.0778 - val_accuracy: 0.9758
# Epoch 22/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0383 - accuracy: 0.9876 - val_loss: 0.0706 - val_accuracy: 0.9780
# Epoch 23/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0370 - accuracy: 0.9885 - val_loss: 0.0832 - val_accuracy: 0.9754
# Epoch 24/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0354 - accuracy: 0.9887 - val_loss: 0.0795 - val_accuracy: 0.9747
# Epoch 25/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0324 - accuracy: 0.9898 - val_loss: 0.1285 - val_accuracy: 0.9616
# Epoch 26/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.0329 - accuracy: 0.9894 - val_loss: 0.0771 - val_accuracy: 0.9768
# Epoch 27/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0294 - accuracy: 0.9908 - val_loss: 0.0765 - val_accuracy: 0.9766
# Epoch 28/50
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0285 - accuracy: 0.9911 - val_loss: 0.0855 - val_accuracy: 0.9757
# Epoch 29/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.0693 - val_accuracy: 0.9789
# Epoch 30/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0260 - accuracy: 0.9915 - val_loss: 0.0701 - val_accuracy: 0.9790
# Epoch 31/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0251 - accuracy: 0.9920 - val_loss: 0.0722 - val_accuracy: 0.9796
# Epoch 32/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0238 - accuracy: 0.9927 - val_loss: 0.0724 - val_accuracy: 0.9780
# Epoch 33/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.0734 - val_accuracy: 0.9793
# Epoch 34/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.0702 - val_accuracy: 0.9791
# Epoch 35/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0210 - accuracy: 0.9935 - val_loss: 0.0734 - val_accuracy: 0.9795
# Epoch 36/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.0736 - val_accuracy: 0.9784
# Epoch 37/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.0689 - val_accuracy: 0.9801
# Epoch 38/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.0855 - val_accuracy: 0.9763
# Epoch 39/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0788 - val_accuracy: 0.9790
# Epoch 40/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.0750 - val_accuracy: 0.9795
# Epoch 41/50
# 469/469 [==============================] - 39s 82ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.0761 - val_accuracy: 0.9799
# Epoch 42/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.0716 - val_accuracy: 0.9806
# Epoch 43/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0152 - accuracy: 0.9956 - val_loss: 0.0744 - val_accuracy: 0.9802
# Epoch 44/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0830 - val_accuracy: 0.9778
# Epoch 45/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.0131 - accuracy: 0.9962 - val_loss: 0.0833 - val_accuracy: 0.9786
# Epoch 46/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0864 - val_accuracy: 0.9788
# Epoch 47/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0805 - val_accuracy: 0.9793
# Epoch 48/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0874 - val_accuracy: 0.9785
# Epoch 49/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0847 - val_accuracy: 0.9781
# Epoch 50/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.0802 - val_accuracy: 0.9797

# %% [markdown]
# Nhận xét độ chính xác: Độ chính xác trên tập train gần như tuyệt đối nhưng trên tập test thì không thay đổi so với kiến trúc mạng gốc.
